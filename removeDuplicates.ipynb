# %% [markdown]
# /*******************************************************
#  * General Public License 2024
#
#  * Authors:
#  *   - Janaka Wijekoon
#  *   - Rashini Liyanarachchi
#
#  * Feel free to make any modifications to the code. If you make any changes, kindly add your name to the authors list.
#
#  *******************************************************/

# %%
import pandas as pd

# %%
df_or = pd.read_excel("/content/drive/MyDrive/Sheet_test.xlsx")

# %%
df_or
# Out:
#                                                  Title  \
# 0    Invited review artificial intelligence to de-e...
# 1    Winter is over: the use of artificial intellig...
# 2    Artificial intelligence in the interpretation ...
# 3    Artificial intelligence for prediction of trea...
# 4    Artificial intelligence in digital breast path...
# ..                                                 ...
# 105  Artificial intelligence applied to breast path...
# 106  Artificial intelligence in cancer research and...
# 107  MRI as a biomarker for breast cancer diagnosis...
# 108  Artificial intelligence and machine learning i...
# 109                                Title not available
#
#                                               Abstract  \
# 0    … breast cancer therapy, with a special focus ...
# 1    … in AI for breast cancer patients, focusing o...
# 2    … In this article we describe the goals of AI ...
# 3    … translation of AI algorithms into clinical p...
# ...

# %%
df_or['Title'] = df_or['Title'].apply(lambda x: x.strip())
df_or['Title'] = df_or['Title'].apply(lambda x: x.lstrip('.'))
df_or['Title'] = df_or['Title'].apply(lambda x: x.rstrip('.'))
df_or
# Out:
#                                                  Title  \
# 0    Invited review artificial intelligence to de-e...
# 1    Winter is over: the use of artificial intellig...
# 2    Artificial intelligence in the interpretation ...
# 3    Artificial intelligence for prediction of trea...
# 4    Artificial intelligence in digital breast path...
# ..                                                 ...
# 105  Artificial intelligence applied to breast path...
# 106  Artificial intelligence in cancer research and...
# 107  MRI as a biomarker for breast cancer diagnosis...
# 108  Artificial intelligence and machine learning i...
# 109                                Title not available
#
#                                               Abstract  \
# 0    … breast cancer therapy, with a special focus ...
# 1    … in AI for breast cancer patients, focusing o...
# 2    … In this article we describe the goals of AI ...
# 3    … translation of AI algorithms into clinical p...
# ...

# %%
#retrieving the duplicated records
df = df_or[df_or.duplicated('Title')]

# %%
df
# Out:
#                                          Title  \
# 21                         Title not available
# 32                         Title not available
# 43                         Title not available
# 54                         Title not available
# 65                         Title not available
# 76                         Title not available
# 87                         Title not available
# 94   Artificial intelligence in breast imaging
# 98                         Title not available
# 109                        Title not available
#
#                                               Abstract  \
# 21                              Abstract not available
# 32                              Abstract not available
# 43                              Abstract not available
# 54                              Abstract not available
# 65                              Abstract not available
# 76                              Abstract not available
# ...

# %%
df = df_or.drop_duplicates('Title')

# %%
df
# Out:
#                                                  Title  \
# 0    Invited review artificial intelligence to de-e...
# 1    Winter is over: the use of artificial intellig...
# 2    Artificial intelligence in the interpretation ...
# 3    Artificial intelligence for prediction of trea...
# 4    Artificial intelligence in digital breast path...
# ..                                                 ...
# 104  Improving DCIS diagnosis and predictive outcom...
# 105  Artificial intelligence applied to breast path...
# 106  Artificial intelligence in cancer research and...
# 107  MRI as a biomarker for breast cancer diagnosis...
# 108  Artificial intelligence and machine learning i...
#
#                                               Abstract  \
# 0    … breast cancer therapy, with a special focus ...
# 1    … in AI for breast cancer patients, focusing o...
# 2    … In this article we describe the goals of AI ...
# 3    … translation of AI algorithms into clinical p...
# ...
